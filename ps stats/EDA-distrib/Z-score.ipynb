# %% [markdown]
# # Z-Score. Puntuación Z
# ###### https://www.chreinvent.com/recursos/puntuaci%C3%B3n-est%C3%A1ndar
# Calculo del valor Z para un valor xi=70 en una distribución con media 50 y desvío = 10.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# Parámetros de la distribución
mu = 50
sigma = 10

# Valores para el gráfico
x = np.linspace(mu - 3*sigma, mu + 3*sigma, 100)
y = stats.norm.pdf(x, mu, sigma)

# Valor específico
x_i = 70
z = (x_i - mu) / sigma

# Crear gráfico
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='Distribución Normal')
plt.axvline(mu, color='r', linestyle='--', label='Media ($\mu$)')
plt.axvline(x_i, color='g', linestyle='--', label=f'Valor ($x_i$), Z={z:.2f}')
plt.fill_between(x, 0, y, where=(x >= mu) & (x <= x_i), color='grey', alpha=0.5)
plt.title('Visualización de la Puntuación Z')
plt.xlabel('Valor')
plt.ylabel('Densidad de Probabilidad')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <>:20: SyntaxWarning: invalid escape sequence '\m'
# <>:20: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Dani\AppData\Local\Temp\ipykernel_18620\2767029389.py:20: SyntaxWarning: invalid escape sequence '\m'
#   plt.axvline(mu, color='r', linestyle='--', label='Media ($\mu$)')
