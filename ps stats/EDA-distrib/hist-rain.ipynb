# %% [markdown]
# # Distribución de Frecuencias - Histogramas
# ## Rain - Lluvia

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# El archivo BosTrain contiene una muestra de las precipitaciones de Boston durante una semana.
# + Observe las distribuciones de la cantidad de precipitaciones para cada día en uno o dos gráficos.
# + Luego analice las precipitaciones del domingo.

# %%
# Lectura de dataset
xlsx = pd.ExcelFile("../../data/BosTrain.xlsx")
df = pd.read_excel(xlsx)

# %%
# Observo el dataset
df.describe()
# Out:
#              Lun        Mar       Miér        Jue        Vie        Sáb  \
# count  52.000000  52.000000  52.000000  52.000000  52.000000  52.000000
# mean    0.100385   0.058462   0.051731   0.068654   0.094615   0.142885
# std     0.262626   0.156774   0.135744   0.167145   0.227996   0.289979
# min     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 25%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 50%     0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 75%     0.010000   0.012500   0.012500   0.040000   0.040000   0.100000
# max     1.410000   0.740000   0.640000   0.850000   0.960000   1.480000
#
#              Dom
# count  52.000000
# mean    0.067692
# std     0.200035
# min     0.000000
# 25%     0.000000
# 50%     0.000000
# 75%     0.010000
# max     1.280000

# %%
# Analizo la cantidad de bins para una anchura de 0.20
df.max()/0.20
# Out:
# Lun     7.05
# Mar     3.70
# Miér    3.20
# Jue     4.25
# Vie     4.80
# Sáb     7.40
# Dom     6.40
# dtype: float64

# %% [markdown]
# ## Precipitaciones totales

# %%
# Grafico todas las precipitaciones de todos los días de la semana
sns.histplot(data=df)
# Out:
# <Axes: ylabel='Count'>

# %%
# Otra vista de las precipitaciones de la muestra
sns.histplot(data=df, bins=10, element='poly')
# Out:
# <Axes: ylabel='Count'>

# %% [markdown]
# ## Precipitaciones del domingo

# %% [markdown]
# + Utilice las 52 cantidades de lluvia del domingo.
# + Analice la distribución de frecuencias iniciando con un límite de clase inferior de 0.00 y utilice una anchura de clase de 0.20.
# + Describa la naturaleza de la distribución.
# + ¿Al parecer se trata de una distribución de frecuencias normal?

# %%
np.histogram(a=df.Dom)
# Out:
# (array([44,  2,  4,  1,  0,  0,  0,  0,  0,  1], dtype=int64),
#  array([0.   , 0.128, 0.256, 0.384, 0.512, 0.64 , 0.768, 0.896, 1.024,
#         1.152, 1.28 ]))

# %%
sns.histplot(data=df.Dom, bins=7, element='step')
# Out:
# <Axes: xlabel='Dom', ylabel='Count'>

# %%
sns.displot(data=df.Dom)

# %% [markdown]
# ##### Conclusiones
# La distribución no parece ser normal.
# + La mayoría de los días no hay precipitación pluvial.
# + La distribución no es simétrica y hay muy pocos días con grandes cantidades de precipitación.
