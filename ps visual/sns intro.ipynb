# %%
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt

import seaborn as sns

# %%
# Apply the default theme
sns.set_theme()

# %%
# Load an example dataset included in seaborn[stats] library
# to be used as an example
tips = sns.load_dataset("tips")
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %%
path = '..\\..\\data\\'
xlsfile = 'usd_arg.xlsx'
pathfile = path + xlsfile
pathfile
# Out:
# '..\\..\\data\\usd_arg.xlsx'

# %%
# read data, set dates as index
df = pd.read_excel(pathfile, sheet_name='blue', index_col=0)

# %%
# sort index ascending
df.sort_index()
# Out:
#             Compra    Venta
# Fecha
# 2002-01-11    1.65     1.70
# 2002-01-14    1.63     1.68
# 2002-01-15    1.90     1.95
# 2002-01-16    1.83     1.87
# 2002-01-17    1.92     1.97
# ...            ...      ...
# 2023-12-29  975.00  1025.00
# 2024-01-02  955.00  1005.00
# 2024-01-03  955.00  1005.00
# 2024-01-04  970.00  1020.00
# 2024-01-05  975.00  1025.00
#
# [5500 rows x 2 columns]

# %%
# Line chart showing daily evolution 
sns.lineplot(data=df)

# set title to...
plt.title("Dolar Blue - Argentina")

# set axis labels to...
plt.xlabel("Año")
plt.ylabel("Valor $")
# Out:
# Text(0, 0.5, 'Valor $')
